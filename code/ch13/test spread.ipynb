# %%
import pandas as pd
import math
import numpy as np
import scipy.stats as scs
import statsmodels.api as sm
from pylab import mpl, plt

# %%
raw = pd.read_csv('../../source/spreads.csv',
                 index_col=0, parse_dates=True).dropna()

# %%
raw1 = pd.read_csv('../../source/tr_eikon_eod_data.csv',
                 index_col=0, parse_dates=True).dropna()

# %%
symbols=['HH','TTF']

# %%
data=raw[symbols]
data=data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2641 entries, 2025-11-04 to 2015-09-22
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HH      2641 non-null   float64
#  1   TTF     2641 non-null   float64
# dtypes: float64(2)
# memory usage: 61.9 KB

# %%
log_returns = np.log(data / data.shift(1))

# %%
round(log_returns.mean()*252,3)
# Out:
# HH    -0.048
# TTF   -0.049
# dtype: float64

# %%
round(log_returns.cov()*252,3)
# Out:
#         HH    TTF
# HH   0.395  0.047
# TTF  0.047  0.519
